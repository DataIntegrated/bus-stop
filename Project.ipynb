# %%
import geopandas as  gpd
import os
import matplotlib.pyplot as plt
import time

# %%
df=gpd.read_file("C:/Users/User 1/Desktop/Bus stops/Kenya Road Network_/Shapefile/Kenya_Road_Network.shp")

# %%
df
# Out:
#        OBJECTID           RdNum  \
# 0             1              A1
# 1             2          A1_IR1
# 2             3          A1_IRe
# 3             4           A1_R1
# 4             5           A1_R2
# ...         ...             ...
# 59033    150276   UCBU6-BUNGOMA
# 59034    150277  UCBU6-KAKAMEGA
# 59035    150278  UCBU6a-BUNGOMA
# 59036    150279  UCBU7-KAKAMEGA
# 59037    150280    UCBU7-MUMIAS
#
#                                                   RdName RdClass    Rdlength  \
# 0      Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migor...       A  891.815158
# 1      Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migor...       A    0.277734
# 2      Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migor...       A    0.142226
# 3      Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migor...       A   11.305380
# 4      Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migor...       A    0.559480
# ...                                                  ...     ...         ...
# ...

# %%
dta=gpd.read_file("C:/Users/User 1/Desktop/Bus stops/Kenya Road Network_/Shapefile/Kenya_Road_Network.dbf")
dta
# Out:
#        OBJECTID           RdNum  \
# 0             1              A1
# 1             2          A1_IR1
# 2             3          A1_IRe
# 3             4           A1_R1
# 4             5           A1_R2
# ...         ...             ...
# 59033    150276   UCBU6-BUNGOMA
# 59034    150277  UCBU6-KAKAMEGA
# 59035    150278  UCBU6a-BUNGOMA
# 59036    150279  UCBU7-KAKAMEGA
# 59037    150280    UCBU7-MUMIAS
#
#                                                   RdName RdClass    Rdlength  \
# 0      Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migor...       A  891.815158
# 1      Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migor...       A    0.277734
# 2      Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migor...       A    0.142226
# 3      Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migor...       A   11.305380
# 4      Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migor...       A    0.559480
# ...                                                  ...     ...         ...
# ...

# %%
dta
# Out:
#        OBJECTID           RdNum  \
# 0             1              A1
# 1             2          A1_IR1
# 2             3          A1_IRe
# 3             4           A1_R1
# 4             5           A1_R2
# ...         ...             ...
# 59033    150276   UCBU6-BUNGOMA
# 59034    150277  UCBU6-KAKAMEGA
# 59035    150278  UCBU6a-BUNGOMA
# 59036    150279  UCBU7-KAKAMEGA
# 59037    150280    UCBU7-MUMIAS
#
#                                                   RdName RdClass    Rdlength  \
# 0      Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migor...       A  891.815158
# 1      Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migor...       A    0.277734
# 2      Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migor...       A    0.142226
# 3      Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migor...       A   11.305380
# 4      Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migor...       A    0.559480
# ...                                                  ...     ...         ...
# ...

# %%
dta1=dta.plot(column="Rdlength" )

# %%
dta=gpd.read_file("C:/Users/User 1/Desktop/Bus stops/Kenya Road Network_/Shapefile/Kenya_Road_Network.dbf")
dta2=dta.plot(column='RdClass')

# %%
import geopandas as gpd
import shapely as shp
from shapely.geometry import linestring

# %%
# !pip install geopy

# %%
import pandas as pd
from geopy.geocoders import Nominatim
df=gpd.read_file("C:/Users/User 1/Desktop/Bus stops/Kenya Road Network_/Shapefile/Kenya_Road_Network.shp")
df[0:20]
# Out:
#     OBJECTID      RdNum                                             RdName  \
# 0          1         A1  Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migor...
# 1          2     A1_IR1  Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migor...
# 2          3     A1_IRe  Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migor...
# 3          4      A1_R1  Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migor...
# 4          5      A1_R2  Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migor...
# 5          6     A1_SRe  Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migor...
# 6          7        A10  A1 LOKICHAR_NGINYANG_ISIOLO_GARISSA_LAMU(LAPSSET)
# 7          8        A11                                        Lamu-kiunga
# 8          9        A12             IBD Busia-Kisumu-Kericho-A8 Mau Summit
# 9         10  A12_ICH13                           Total-Kericho-Ahero Rd_2
# 10        11  A12_ICH14                           Total-Kericho-Ahero Rd_1
# ...

# %%
import pandas as pd
from geopy.geocoders import Nominatim
df=gpd.read_file("C:/Users/User 1/Desktop/Bus stops/Kenya Road Network_/Shapefile/Kenya_Road_Network.shp")

from urllib.request import urlopen
with urlopen("https://drive.google.com/file/d/1Gxo6cxPKB38HKffc57MRtDtFcPmFhYaP/view?usp=sharing") as response:
    body = response.read()
character_set = response.headers.get_content_charset()
character_set = 'utf-8'
decoded_body = body.decode(character_set)
print(decoded_body[:20])
df.geometry[0:20]


# df.geometry[0:20]
# df["query"]= df["RdName"]+""+df["RdNum"]
# df.drop_duplicates(subset="query", inplace= True)
# Out:
# <!doctype html><html
# 0     MULTILINESTRING ((-30859.260 10492745.857, -30...
# 1     LINESTRING (54974.575 10109936.296, 55005.951 ...
# 2     LINESTRING (55234.283 10110248.941, 55188.749 ...
# 3     MULTILINESTRING ((55166.179 10110130.280, 5516...
# 4     LINESTRING (55192.762 10110468.285, 55191.042 ...
# 5     LINESTRING (54974.575 10109936.296, 55007.106 ...
# 6     MULTILINESTRING ((-16322.148 10466732.066, -16...
# 7     LINESTRING (690937.842 9793980.272, 690938.157...
# 8     MULTILINESTRING ((-45981.049 10051601.054, -45...
# 9     LINESTRING (131022.678 9982373.313, 131031.168...
# 10    LINESTRING (131797.625 9982671.097, 131792.572...
# 11    LINESTRING (23877.560 9991464.659, 23920.650 9...
# 12    LINESTRING (131271.335 9982350.177, 131277.967...
# 13    LINESTRING (24126.627 9991434.420, 24177.113 9...
# 14    MULTILINESTRING ((710174.744 10341531.736, 710...
# 15    MULTILINESTRING ((510497.596 10383537.586, 510...
# ...

# %%
df1=df.drop(columns=["RdNum"])

# %%
# !pip install folium

# %%
import pandas as pd
import os;
import sys;
sys.executable
print(sys.path)
# Out:
# ['C:\\Users\\User 1\\Desktop\\Bus stops\\Kenya Road Network_\\bus_stop', 'C:\\Users\\User 1\\AppData\\Local\\Programs\\Python\\Python310\\python310.zip', 'C:\\Users\\User 1\\AppData\\Local\\Programs\\Python\\Python310\\DLLs', 'C:\\Users\\User 1\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\Users\\User 1\\AppData\\Local\\Programs\\Python\\Python310', '', 'C:\\Users\\User 1\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages', 'C:\\Users\\User 1\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\win32', 'C:\\Users\\User 1\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\win32\\lib', 'C:\\Users\\User 1\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\Pythonwin']

# %%
#  data=gpd.read_file("C:/Users/User 1/Desktop/Bus stops/Kenya Road Network_/Shapefile/Kenya_Road_Network.shp")
# data.geometry
! pip install sklearn
# !pip install JAROWINKLER_SIMILARITY

# %%
# !pip install jarowinkler

# %%
! pip install similarity
# Out:
# ...
#   Using cached similarity-0.0.1-py3-none-any.whl (8.3 kB)
# ...
#   Using cached editdistance-0.6.0.tar.gz (29 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
# Using legacy 'setup.py install' for editdistance, since package 'wheel' is not installed.
# ...
#   Running setup.py install for editdistance: started
#   Running setup.py install for editdistance: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Running setup.py install for editdistance did not run successfully.
#   exit code: 1
#
#   [14 lines of output]
#   running install
#   C:\Users\User 1\AppData\Local\Programs\Python\Python310\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-310
# ...

# %%
import pandas as pd 
import numpy as np 
import geopandas as gpd
from geopy.geocoders import Nominatim 
from sklearn.feature_extraction.text import TfidfVectorizer

#from similarity.jarowinkler import JaroWinkler
#from similarity.jaro_winkler import  jarowinkler
#from similarity.cosine import Cosine

# %%
pd.set_option('display.max_colwidth', 3000)

# %%
df=gpd.read_file("C:/Users/User 1/Desktop/Bus stops/Kenya Road Network_/Shapefile/Kenya_Road_Network.shp",index_col="geometry")
df.head(200)
# Out:
#      OBJECTID   RdNum  \
# 0           1      A1
# 1           2  A1_IR1
# 2           3  A1_IRe
# 3           4   A1_R1
# 4           5   A1_R2
# ..        ...     ...
# 195       196    C237
# 196       197    C238
# 197       198    C251
# 198       199    C252
# 199       200    C253
#
#                                                            RdName RdClass  \
# 0    Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migori-Ibd Isebania       A
# 1    Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migori-Ibd Isebania       A
# 2    Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migori-Ibd Isebania       A
# 3    Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migori-Ibd Isebania       A
# 4    Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migori-Ibd Isebania       A
# ..                                                            ...     ...
# 195                                      BAMBA _ GANZE _ MAGOGONI       C
# 196                                                  RIBE_MAERENI       C
# ...

# %%
Ndf=df[["RdName", "geometry"]]
Ndf
# Out:
#                                                              RdName  \
# 0      Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migori-Ibd Isebania
# 1      Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migori-Ibd Isebania
# 2      Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migori-Ibd Isebania
# 3      Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migori-Ibd Isebania
# 4      Ibd Nakadok-Lodwar-Kitale-Bungoma-Kisumu-Migori-Ibd Isebania
# ...                                                             ...
# 59033                                          Kanduyi-Bungoma Rd_4
# 59034                                        Rosterman Pri-Kakamega
# 59035                                          Kanduyi-Bungoma Rd_4
# 59036                        Sichirai-Kakamega-Mumias Township Rd_2
# 59037                                        Matungu-Mayoni-Kholera
#
# ...

# %%
import time
from pprint import pprint
loca= Nominatim(user_agent="geocoding")
location = loca.geocode("Nairobi, Kenya").raw
pprint(location)
# Out:
# {'boundingbox': ['-1.444471', '-1.1635224', '36.6509378', '37.1038871'],
#  'class': 'place',
#  'display_name': 'Nairobi, Kenya',
#  'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_place_city.p.20.png',
#  'importance': 0.845026759433763,
#  'lat': '-1.30326415',
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. '
#             'https://osm.org/copyright',
#  'lon': '36.826384099341595',
#  'osm_id': 9185096,
#  'osm_type': 'relation',
#  'place_id': 298279563,
#  'type': 'city'}

# %%
def get_address_by_location(latitude, longitude, language="en"):
   
    # build coordinates string to pass to reverse() function
    coordinates = f"{latitude}, {longitude}"
    # sleep for a second to respect Usage Policy
    time.sleep(1)
    try:
        return loca.reverse(coordinates, language=language).raw
    except:
        return get_address_by_location(latitude, longitude)

# %%
latitude = [ -30859.260,-30651.905 ]
longitude = [10492745.857,10492607.277 ]
# get the address info
address = get_address_by_location(latitude, longitude)
# print all returned data
pprint(address)

# %%
import geopandas as gp
import shapely
import pandas as pd
# %matplotlib inline
DataF = pd.DataFrame(data=Ndf, columns=['LAT', 'LON'])
Ndf1 = gp.GeoDataFrame(DataF)
